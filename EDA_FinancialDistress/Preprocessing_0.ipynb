# %%
from scipy.io import arff
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data0 = arff.loadarff('1year.arff')

# %%
df0 = pd.DataFrame(data0[0])

# %%
data1 = arff.loadarff('2year.arff')

# %%
df1 = pd.DataFrame(data1[0])

# %%
data2 = arff.loadarff('3year.arff')
df2 = pd.DataFrame(data2[0])

# %%
data3 = arff.loadarff('4year.arff')
df3 = pd.DataFrame(data3[0])

# %%
df0.shape
# Out:
# (7027, 65)

# %%
df1.shape
# Out:
# (10173, 65)

# %%
df2.shape
# Out:
# (10503, 65)

# %%
df3.shape
# Out:
# (9792, 65)

# %%
df = [df0,df1, df2, df3]

# %%
df = pd.concat(df)

# %%
df.shape
# Out:
# (37495, 65)

# %%
df.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7    Attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     Attr9   Attr10  ...    Attr56   Attr57   Attr58    Attr59  Attr60  Attr61  \
# 0  1.1389  0.50494  ...  0.121960  0.39718  0.87804  0.001924  8.4160  5.1372
# 1  1.6996  0.49788  ...  0.121300  0.42002  0.85300  0.000000  4.1486  3.2732
# 2  1.3090  0.30408  ...  0.241140  0.81774  0.76599  0.694840  4.9909  3.9510
# 3  1.0571  0.57353  ...  0.054015  0.14207  0.94598  0.000000  4.5746  3.6147
# 4  1.1559  0.38677  ...  0.134850  0.48431  0.86515  0.124440  6.3985  4.3158
#
#     Attr62  Attr63   Attr64  class
# ...

# %%
df['class'].unique()
# Out:
# array([b'0', b'1'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
df['class'] = le.fit_transform(df['class'])

# %%
df.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7    Attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     Attr9   Attr10  ...    Attr56   Attr57   Attr58    Attr59  Attr60  Attr61  \
# 0  1.1389  0.50494  ...  0.121960  0.39718  0.87804  0.001924  8.4160  5.1372
# 1  1.6996  0.49788  ...  0.121300  0.42002  0.85300  0.000000  4.1486  3.2732
# 2  1.3090  0.30408  ...  0.241140  0.81774  0.76599  0.694840  4.9909  3.9510
# 3  1.0571  0.57353  ...  0.054015  0.14207  0.94598  0.000000  4.5746  3.6147
# 4  1.1559  0.38677  ...  0.134850  0.48431  0.86515  0.124440  6.3985  4.3158
#
#     Attr62  Attr63   Attr64  class
# ...

# %%
df['class'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
pd.set_option('display.max_columns', 65)

# %%
df.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7    Attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     Attr9   Attr10    Attr11   Attr12    Attr13    Attr14   Attr15   Attr16  \
# 0  1.1389  0.50494  0.249760  0.65980  0.166600  0.249760   497.42  0.73378
# 1  1.6996  0.49788  0.261140  0.51680  0.158350  0.258340   677.96  0.53838
# 2  1.3090  0.30408  0.312580  0.64184  0.244350  0.309060   794.16  0.45961
# 3  1.0571  0.57353  0.092704  0.30163  0.094257  0.092704   917.01  0.39803
# 4  1.1559  0.38677  0.187320  0.33147  0.121820  0.187320  1133.20  0.32211
#
# ...

# %%
df.describe()
# Out:
#               Attr1         Attr2         Attr3         Attr4         Attr5  \
# count  37490.000000  37490.000000  37490.000000  37382.000000  3.741700e+04
# mean       0.044220      0.609927      0.102657      6.538754 -4.491582e+02
# std        2.095612      5.856861      5.833509    315.776182  6.533720e+04
# min     -256.890000    -72.162000   -479.960000     -0.045319 -1.190300e+07
# 25%        0.003347      0.270900      0.018382      1.043025 -4.991300e+01
# 50%        0.050148      0.474755      0.193150      1.556900 -1.285800e+00
# 75%        0.131507      0.692150      0.400682      2.768775  5.088900e+01
# max       94.280000    480.960000     22.769000  53433.000000  1.034100e+06
#
#               Attr6         Attr7         Attr8         Attr9        Attr10  \
# count  37490.000000  37490.000000  37419.000000  37487.000000  37490.000000
# mean      -0.068506      0.125846     13.727732      2.819858      0.639676
# ...

# %%
df.fillna(df.median(), inplace=True)

# %%
pd.set_option('display.max_rows', 65)
df.isna().sum()
# Out:
# Attr1     0
# Attr2     0
# Attr3     0
# Attr4     0
# Attr5     0
# Attr6     0
# Attr7     0
# Attr8     0
# Attr9     0
# Attr10    0
# Attr11    0
# Attr12    0
# Attr13    0
# Attr14    0
# Attr15    0
# Attr16    0
# Attr17    0
# Attr18    0
# Attr19    0
# Attr20    0
# Attr21    0
# Attr22    0
# Attr23    0
# Attr24    0
# Attr25    0
# Attr26    0
# Attr27    0
# Attr28    0
# Attr29    0
# Attr30    0
# Attr31    0
# Attr32    0
# Attr33    0
# Attr34    0
# Attr35    0
# Attr36    0
# Attr37    0
# Attr38    0
# Attr39    0
# Attr40    0
# Attr41    0
# Attr42    0
# Attr43    0
# Attr44    0
# Attr45    0
# Attr46    0
# Attr47    0
# Attr48    0
# Attr49    0
# Attr50    0
# Attr51    0
# Attr52    0
# Attr53    0
# Attr54    0
# Attr55    0
# Attr56    0
# Attr57    0
# Attr58    0
# Attr59    0
# Attr60    0
# Attr61    0
# Attr62    0
# Attr63    0
# Attr64    0
# class     0
# dtype: int64

# %%
df.dtypes
# Out:
# Attr1     float64
# Attr2     float64
# Attr3     float64
# Attr4     float64
# Attr5     float64
# Attr6     float64
# Attr7     float64
# Attr8     float64
# Attr9     float64
# Attr10    float64
# Attr11    float64
# Attr12    float64
# Attr13    float64
# Attr14    float64
# Attr15    float64
# Attr16    float64
# Attr17    float64
# Attr18    float64
# Attr19    float64
# Attr20    float64
# Attr21    float64
# Attr22    float64
# Attr23    float64
# Attr24    float64
# Attr25    float64
# Attr26    float64
# Attr27    float64
# Attr28    float64
# Attr29    float64
# Attr30    float64
# Attr31    float64
# Attr32    float64
# Attr33    float64
# Attr34    float64
# Attr35    float64
# Attr36    float64
# Attr37    float64
# Attr38    float64
# Attr39    float64
# Attr40    float64
# Attr41    float64
# Attr42    float64
# Attr43    float64
# Attr44    float64
# Attr45    float64
# Attr46    float64
# Attr47    float64
# Attr48    float64
# Attr49    float64
# Attr50    float64
# ...

# %%
# let's see how data is distributed for every column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=16 :     
        ax = plt.subplot(4,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()

# %%
# let's see how data is distributed for every column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df.iloc[:, 16:]:
    if plotnumber<=16 :     
        ax = plt.subplot(4,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()

# %%
# let's see how data is distributed for every column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df.iloc[:, 32:]:
    if plotnumber<=16 :     
        ax = plt.subplot(4,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()

# %%
# let's see how data is distributed for every column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df.iloc[:, 48:]:
    if plotnumber<=16 :     
        ax = plt.subplot(4,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.boxplot(data=df.iloc[:, :16], width= 0.5,ax=ax,  fliersize=3)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.boxplot(data=df.iloc[:, 16:32], width= 0.5,ax=ax,  fliersize=3)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.boxplot(data=df.iloc[:, 32:48], width= 0.5,ax=ax,  fliersize=3)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.boxplot(data=df.iloc[:, 48:64], width= 0.5,ax=ax,  fliersize=3)
plt.show()

# %%
f,ax = plt.subplots(figsize=(30, 30))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
y = df['class']
X =df.drop(columns = ['class'])

# %%
from sklearn.preprocessing import StandardScaler 

scalar = StandardScaler()
X_scaled = scalar.fit_transform(X)

# %%
X_scaled
# Out:
# array([[ 0.07460412, -0.0393414 ,  0.05035809, ..., -0.01078539,
#         -0.03896634, -0.02741763],
#        [ 0.07869394, -0.0187878 ,  0.06335988, ..., -0.01062034,
#         -0.04696534, -0.00490748],
#        [ 0.09756345,  0.01468674,  0.02819469, ..., -0.01044039,
#         -0.05233187, -0.02835062],
#        ...,
#        [-0.13482166,  0.00293206, -0.00210785, ..., -0.01074378,
#         -0.04140195, -0.03020525],
#        [ 0.0252771 ,  0.02443335, -0.07377782, ..., -0.00988718,
#         -0.06049545, -0.02998498],
#        [-0.01088325, -0.02102467,  0.00793254, ..., -0.01068003,
#         -0.04453603, -0.02846759]])

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = X_scaled

# we create a new data frame which will include all the VIFs
# note that each variable has its own variance inflation factor as this measure is variable specific (not model specific)
# we do not include categorical values for mulitcollinearity as they do not provide much information as numerical ones do
vif = pd.DataFrame()

# here we make use of the variance_inflation_factor, which will basically output the respective VIFs 
vif["VIF"] = [variance_inflation_factor(variables, i) for i in range(variables.shape[1])]
# Finally, I like to include names so it is easier to explore the result
vif["Features"] = X.columns

# %%
vif
# Out:
#              VIF Features
# 0   1.344922e+01    Attr1
# 1   3.486679e+02    Attr2
# 2   4.768958e+02    Attr3
# 3   7.340252e+03    Attr4
# 4   1.004068e+00    Attr5
# 5   1.098621e+01    Attr6
# 6   4.085028e+08    Attr7
# 7   8.115016e+03    Attr8
# 8   9.865727e+02    Attr9
# 9   6.160116e+03   Attr10
# 10  3.164416e+02   Attr11
# 11  8.451581e+01   Attr12
# 12  1.443244e+02   Attr13
# 13  4.104794e+08   Attr14
# 14  1.002514e+00   Attr15
# 15  5.918895e+02   Attr16
# 16  8.144931e+03   Attr17
# 17  4.525692e+03   Attr18
# 18  1.596858e+03   Attr19
# 19  6.075641e+09   Attr20
# 20  1.000319e+00   Attr21
# 21  1.690648e+02   Attr22
# 22  7.675861e+02   Attr23
# 23  5.993058e+00   Attr24
# 24  4.275394e+01   Attr25
# 25  4.146818e+02   Attr26
# 26  1.001595e+00   Attr27
# 27  1.395491e+00   Attr28
# 28  1.196827e+00   Attr29
# 29  1.893812e+01   Attr30
# 30  9.144773e+02   Attr31
# 31  8.491387e+00   Attr32
# 32  1.979848e+02   Attr33
# 33  1.939258e+01   Attr34
# ...

# %%
from imblearn.over_sampling import SMOTE


smt = SMOTE()
X, y = smt.fit_sample(X, y)

# %%
np.bincount(y)
# Out:
# array([35814, 35814], dtype=int64)

# %%
X.shape
# Out:
# (71628, 64)

# %%
df['class'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
from sklearn.decomposition import PCA
pca = PCA()
principalComponents = pca.fit_transform(df)
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('Explained Variance')
plt.show()

# %%
pca = PCA(n_components=5)
new_data = pca.fit_transform(df)
# This will be the new data fed to the algorithm.
principal_Df = pd.DataFrame(data = new_data
             , columns = ['principal component 1', 'principal component 2','principal component 3','principal component 4', 'principal component 5'])

# %%
principal_Df.head()
# Out:
#    principal component 1  principal component 2  principal component 3  \
# 0           -2250.524141           -1475.480893           -1119.004781
# 1           -1998.798828            -930.633048           -1494.343817
# 2           -2018.139076            -885.175931           -1371.092982
# 3           -2037.444600            -990.317803           -1228.849397
# 4           -2042.309660            -917.200801           -1037.246255
#
#    principal component 4  principal component 5
# 0          341439.628255            5620.025236
# 1           -4855.653812            -461.592291
# 2            -829.542828            -381.479896
# 3           13380.550917            -194.311856
# 4           -3975.240558            -453.036665
